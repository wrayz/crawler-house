# %%
import requests
import requests.packages.urllib3.util.ssl_
requests.packages.urllib3.util.ssl_.DEFAULT_CIPHERS = 'ALL'

# %%
url = 'https://www.booking.com/reviewlist.zh-tw.html?aid=304142;label=gen173nr-1DCFQoggJCDXBlbmdodS1jb3VudHlIMFgEaOcBiAEBmAEwuAEYyAEM2AED6AEB-AECiAIBqAIEuALF2brlBcACAQ;sid=4944c5d358ddefa93474659f3ae11e27;srpvid=7db54af69e6a000f&;cc1=tw&pagename=yalinghotel&r_lang=&review_topic_category_id=&dist=1&offset=0&rows=10&rurl=&score=&sort=&type=total&_=155498396'
# header 注意那個 Accept-Encoding, 那是請求 gzip 編碼，所以回來就會變成亂碼，不如不放
headers = {
#     'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
#     'Accept-Encoding': 'gzip, deflate, br',
#     'Accept-Language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6',
#     'Connection': 'keep-alive',
#     'Host': 'www.booking.com',
#     'Upgrade-Insecure-Requests': '1',
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.103 Safari/537.36'
}
r = requests.get(url, headers=headers)

# %%
r.text
# Out:
# '<script src="https://q-cf.bstatic.com/static/js/reviewlist_cloudfront/9461a59f2cddce80168b6ddb84456cd9db9f3ccf.js" crossorigin></script>\n<input name="highlight_text" type="hidden" value="">\n<div class="bui-panel-group bui-panel-group--reviewlist" style="margin-top: -1px;">\n</div>\n<ul class="review_list">\n<li class="review_list_new_item_block">\n<div class="c-review-block c-review-block_helpful_replace" itemprop="review" itemscope itemtype="http://schema.org/Review">\n<div itemprop="publisher" itemscope itemtype="http://schema.org/Organization">\n<meta itemprop="name" content="Booking.com B.V.">\n</div>\n<div class="c-review-block__row">\n<div class="c-guest-with-score">\n            <div class="c-guest-with-score__guest"><div class="c-guest bui-avatar-block"><div class="bui-avatar "><span class="c-avatar__loginicon bicon-mybooking"></span></div><div class="bui-avatar-block__text">\n                <span class="bui-avatar-block__title">&#x7FFC;</span><span class="bui-avatar-bloc
# ...
