# %%
import pandas as pd

# %%
df = pd.read_csv('0403.csv')
df['證券代號'] = df['證券代號'].str.strip('=, "')
df.drop('Unnamed: 16', axis=1, inplace=True)

# %%
df
# Out:
#          證券代號       證券名稱         成交股數    成交筆數           成交金額     開盤價     最高價  \
# 0        0050     元大台灣50    5,605,092   2,132    449,896,022   80.10   80.45
# 1        0051    元大中型100       26,940      14        860,770   31.87   31.95
# 2        0052       富邦科技      103,007       8      5,577,927   54.30   54.30
# 3        0053       元大電子        1,000       1         34,820   34.82   34.82
# 4        0054     元大台商50       44,000      21        983,120   22.30   22.46
# 5        0055   元大MSCI金融        7,000       5        122,160   17.48   17.48
# 6        0056      元大高股息    2,905,223   1,530     77,238,764   26.52   26.64
# 7        0057       富邦摩台       22,000       5      1,111,850   50.45   50.55
# 8        0058       富邦發達       22,000       5      1,019,080   46.34   46.34
# 9        0059       富邦金融        2,000       2         87,690   44.02   44.02
# 10       0061      元大寶滬深    3,050,012     742     57,373,732   18.82   18.86
# ...
